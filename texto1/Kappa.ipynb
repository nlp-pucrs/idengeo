# %%
import collections
import re
import pandas as pd

dictF = collections.OrderedDict()
anotador = 0
cont = 1
str1 = ""

for filename in ['Clear_01_1_ISO_Andressa_Bressani.xml','Clear_01_1_ISO_Eric_Eltz.xml', 'Clear_01_1_ISO_Keli_Schell.xml' ]:
    
    with open(filename,'r') as file:
        cont = 1
        for line in file:

            if line.find("EM-ID") >= 0 and line.find("/EM") >= 0:
                str1 = re.findall('(?<=>).*?(?=<)', line)[0] + " - " + str(cont)
                categoria = re.findall('(?<=CATEG=").*?(?=")', line)[0]
                print(str1)
                if str1 in dictF:
                    dictF[str1][anotador] = categoria
                else:
                    dictF[str1] = ['','','']
                    dictF[str1][anotador] = categoria
            
            elif line.find("EM-ID") >= 0:
                str1 = re.findall('(?<=>).*?(?=$)', line)[0]
                str1 = str1.replace("\n", "")
                categoria = re.findall('(?<=CATEG=").*?(?=")', line)[0]
            
            elif line.find("/EM") >= 0:
                str1 = str1 + " " + re.findall('(?<=^).*?(?=<)', line)[0] + " - " + str(cont)
                str1 = str1.replace("\n", "")
                if str1 in dictF:
                    dictF[str1][anotador] = categoria
                else:
                    dictF[str1] = ['','','']
                    dictF[str1][anotador] = categoria
                str1 = ""
            
            else:
                str1 = str1 + " " + line
                
            cont += 1
        
    anotador += 1
    
print(len(dictF))
    
pd.DataFrame.from_dict(dictF,orient='index').to_csv('kappa_texto1.csv')
# Out:
# neoproterozoicas - 41
# Fanerozoico - 58
# fanerozoicas - 326
# Pré-Cambriano - 402
# pré-cambriano - 428
# dobramentos - 450
# empurrões - 452
# neoproterozoica - 556
# Falhamentos - 613
# transcorrente - 622
# Pré-Cambriano - 719
# Pré-Cambriano - 744
# falhas - 811
# dobras - 844
# antiformas - 862
# Dobramentos - 881
# Pré-Cambriano - 905
# falhas - 911
# transcorrência - 950
# Paleoproterozóico - 1115
# mesoproterozoicos - 1118
# neoproterozoicos - 1121
# Neoproterozoico - 1167
# Arqueana - 1258
# Paleoproterozóico - 1264
# Neoproterozoico - 1266
# fanerozoico - 1339
# falhas - 1419
# Cretáceo - 1473
# Cenozoico - 1491
# fraturas - 1502
# falhas - 1504
# Neogeno - 1537
# pré-cambriano - 1546
# falhamentos - 3593
# cisalhamento - 3799
# cisalhamento - 3834
# Mesozoico - 3945
# Pré-Cambriano - 3986
# pré-cambrianas - 4095
# transcorrência - 4439
# cisalhamento - 6
# neoproterozoicas - 41
# Fanerozoico - 58
# Cisalhamento - 99
# magnético-estrutural - 124
# cisalhamento - 155
# Cisalhamento - 174
# magnética-estrutural - 290
# Cisalhamento - 294
# fanerozoicas - 326
# Pré-Cambriano - 402
# Paraná - 416
# pré-cambriano - 428
# Cisalhamento - 432
# dobramentos - 450
# empurrões - 452
# tectono-estratigráficos - 494
# cavalgamento - 500
# Cisalhamento - 513
# meso - 554
# neoproterozoica - 556
# Apiaí - 576
# Curitiba - 578
# Paranaguá - 583
# Falhamentos - 613
# Paraíba-Cubatão-Lancinha - 615
# transcorrente - 622
# destral - 627
# Apiaí - 674
# Curitiba - 679
# Pré-Cambriano - 719
# Pré-Cambriano - 744
# cavalgamentos - 768
# Setuva - 813
# Betara - 815
# Tranqueira - 817
# Setuva - 864
# Cerne - 866
# Betara - 868
# Vuturuvu - 875
# transcorrentes - 902
# Pré-Cambriano - 905
# Lancinha - 913
# Cerne - 918
# Lancinha - 945
# tardi-colisional - 956
# Itapirapuã - 1005
# Itaiacoca - 1009
# gnáissicos - 1113
# Paleoproterozóico - 1115
# metassedimentos - 1117
# mesoproterozoicos - 1118
# granitos - 1120
# neoproterozoicos - 1121
# metassedimentares - 1137
# granitos - 1139
# Apiaí - 1152
# Neoproterozoico - 1167
# gnáissico - 1204
# Curitiba - 1215
# Arqueana - 1258
# Paleoproterozóico - 1264
# Neoproterozoico - 1266
# gnáissicas - 1279
# graníticas - 1317
# granitos - 1323
# fanerozoico - 1339
# basaltos - 1456
# Cretáceo - 1473
# Cenozoico - 1491
# lineamento - 1656
# Cisalhamento - 2270
# diabásio - 2612
# embasamento - 2907
# magnético-estrutural - 2974
# diabásio - 3085
# magnético-estrutural - 3201
# embasamento - 3210
# cisalhamento - 3279
# embasamento - 3438
# Cisalhamento - 3475
# sigmoidal - 3484
# cisalhamento - 3490
# magnética-estrutural - 3520
# cisalhamento - 3525
# falhamentos - 3593
# cisalhamento - 3717
# cisalhamento - 3799
# cisalhamento - 3834
# Apiaí - 3908
# Curitiba - 3910
# Mesozoico - 3945
# cisalhamento - 3978
# Pré-Cambriano - 3986
# magnético-estrutural - 4086
# pré-cambrianas - 4095
# cisalhamento - 4100
# sigmoidal - 4143
# embasamento - 4363
# cisalhamento - 4415
# transcorrência - 4439
# cisalhamento - 4489
# embasamento - 4590
# sigmoidal - 4608
# neoproterozoicas - 41
# Fanerozoico - 58
# fanerozoicas - 326
# Pré-Cambriano - 402
# pré-cambriano - 428
# meso - 554
# neoproterozoica - 556
# embasamento - 598
# transcorrente - 622
# destral - 627
# tectônico - 670
# Pré-Cambriano - 719
# Pré-Cambriano - 744
# deformação - 754
# foliações - 789
# estratos - 797
# isoclinais - 803
# falhas - 811
# dobras - 844
# deformação - 896
# Pré-Cambriano - 905
# falhas - 911
# tardi-colisional - 956
# subducção - 993
# lineamento - 1003
# sutura - 1033
# colisão - 1044
# Paleoproterozóico - 1115
# metassedimentos - 1117
# mesoproterozoicos - 1118
# neoproterozoicos - 1121
# embasamento - 1134
# Neoproterozoico - 1167
# embasamento - 1203
# Arqueana - 1258
# Paleoproterozóico - 1264
# Neoproterozoico - 1266
# fanerozoico - 1339
# embasamento - 1351
# tectônica - 1356
# falhas - 1419
# estrias - 1452
# Cretáceo - 1473
# Cenozoico - 1491
# fraturas - 1502
# falhas - 1504
# Neogeno - 1537
# embasamento - 1545
# pré-cambriano - 1546
# embasamento - 1652
# lineamento - 1656
# embasamento - 1673
# alinhamento - 1693
# embasamento - 1698
# diques - 2293
# diques - 2347
# embasamento - 2907
# diques - 3176
# embasamento - 3210
# lineamentos - 3297
# embasamento - 3438
# magnética-estrutural - 3520
# falhamentos - 3593
# diques - 3698
# deformação - 3777
# desmagnetização - 3794
# cisalhamento - 3799
# desmagnetização - 3823
# tectônicos - 3884
# tectônicos - 3926
# intrusão - 3936
# diques - 3940
# Mesozoico - 3945
# Pré-Cambriano - 3986
# pré-cambrianas - 4095
# convergência - 4137
# sigmoidal - 4143
# embasamento - 4363
# tectônico - 4380
# transcorrência - 4439
# sutura - 4446
# desmagnetização - 4458
# diques - 4523
# sigmoidal - 4608
# 286
