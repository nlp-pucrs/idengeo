# %%
import collections
import re
import pandas as pd

dictF = collections.OrderedDict()
anotador = 0
cont = 1
str1 = ""

for filename in ['Clear_07_3_ISO_Andressa_Bressane.xml','Clear_07_3_ISO_Eric_Eltz.xml', 'Clear_07_3_ISO_Keli_Schell.xml' ]:
    
    with open(filename,'r') as file:
        cont = 1
        for line in file:

            if line.find("EM-ID") >= 0 and line.find("/EM") >= 0:
                str1 = re.findall('(?<=>).*?(?=<)', line)[0] + " - " + str(cont)
                categoria = re.findall('(?<=CATEG=").*?(?=")', line)[0]
                print(str1)
                if str1 in dictF:
                    dictF[str1][anotador] = categoria
                else:
                    dictF[str1] = ['','','']
                    dictF[str1][anotador] = categoria
            
            elif line.find("EM-ID") >= 0:
                str1 = re.findall('(?<=>).*?(?=$)', line)[0]
                str1 = str1.replace("\n", "")
                categoria = re.findall('(?<=CATEG=").*?(?=")', line)[0]
            
            elif line.find("/EM") >= 0:
                str1 = str1 + " " + re.findall('(?<=^).*?(?=<)', line)[0] + " - " + str(cont)
                str1 = str1.replace("\n", "")
                print(str1)
                if str1 in dictF:
                    dictF[str1][anotador] = categoria
                else:
                    dictF[str1] = ['','','']
                    dictF[str1][anotador] = categoria
                str1 = ""
            
            else:
                str1 = str1 + " " + line
                
            cont += 1
        
    anotador += 1
    
print(len(dictF))
    
pd.DataFrame.from_dict(dictF,orient='index').to_csv('kappa_texto1.csv')
# Out:
# Bacia de Irecê - 13
# neoproterozoicas - 21
# Cráton do São Francisco - 29
# cinturão epidérmico de antepaís - 60
# cinturão epidérmico de antepaís - 109
# Bacia de Irecê - 113
# Cráton do São Francisco - 143
# dobras e falhas E-W - 162
# bacia - 167
# falhas direcionais - 176
# cinturão - 189
# Cinturão de Antepaís - 229
# Bacia de Irecê - 233
# unidades carbonáticas - 278
# Grupo Una - 281
# substrato quartzítico - 285
# Supergrupo Espinhaço - 288
# Bacia de Irecê - 294
# Cinturão epidérmico de antepaís - 299
# Bacia de Irecê - 324
# neoproterozoicas - 342
# Cráton do São Francisco - 351
# bacia - 365
# Grupo Una - 399
# cinturão epidérmico de antepaís - 408
# cinturão - 416
# cinturão epidérmico de antepaís - 473
# Cráton do São Francisco - 503
# Pré-cambriano - 506
# neoproterozoicas - 519
# bacia - 521
# cinturão epidérmico - 566
# bacia - 607
# cinturão - 627
# cinturão epidérmico de antepaís - 637
# neoproterozoicos - 642
# Bacia de Irecê - 646
# cinturão - 691
# neoproterozoico - 692
# Cráton do São Francisco - 702
# Bacia de Irecê - 712
# Cráton do São Francisco - 721
# pré-cambrianos - 734
# Supergrupo Espinhaço - 737
# Grupo Una - 741
# arqueano - 747
# paleoproterozoico - 749
# Supergrupo Espinhaço - 766
# paleo - 768
# mesoproterozoico - 770
# Bacia de Irecê - 780
# siliciclástica - 788
# rift-sag - 824
# Grupo Una - 828
# neoproterozoica - 832
# Supergrupo Espinhaço - 841
# discordância erosiva - 847
# Bacia de Irecê - 859
# formações Bebedouro e Salitre - 867
# Formação Bebedouro - 871
# diamictitos - 876
# pelitos - 878
# arenitos - 880
# Formação Bebedouro - 918
# Formação Salitre - 922
# Bacia de Irecê - 931
# sucessão carbonática - 937
# ciclos regressivo-transgressivos - 960
# Pré-Cambrianas - 977
# Fanerozoica - 982
# pré-cambrianas - 1033
# Supergrupo Espinhaço - 1069
# Grupo Una - 1075
# paleo - 1197
# mesoproterozoicas - 1199
# cinturão epidérmico de antepaís - 1212
# cinturão - 1220
# Bacia de Irecê - 1229
# sucessões carbonáticas - 1237
# neoproterozoicas - 1238
# Grupo Una - 1241
# cinturão epidérmico de antepaís - 1247
# Bacia de Irecê - 1251
# neoproterozoicas - 1283
# Grupo Una - 1286
# Bacia de Irecê - 1327
# Cráton do São Francisco - 1341
# carbonatos - 1344
# Formação Salitre - 1347
# sucessão carbonática - 1386
# Bacia de Irecê - 1416
# Grupo Una - 1540
# Supergrupo Espinhaço - 1546
# sucessões carbonáticas - 1554
# cinturão epidérmico - 1563
# Bacia de Irecê - 1571
# Bacia de Irecê - 1579
# cinturão epidérmico - 1583
# Bacia de Irecê - 1622
# cinturão epidérmico - 1736
# Bacia de Irecê - 1740
# cinturão - 1822
# coberturas carbonáticas - 1983
# Grupo Una - 1986
# folhelhos - 2612
# argilitos - 2614
# margas - 2616
# Bacia de Irecê - 2662
# cinturão - 2732
# cinturão - 2778
# cinturões epidérmicos - 2843
# cinturões epidérmicos - 2905
# cinturões epidérmicos - 3027
# cinturão - 3067
# cinturão - 3103
# cinturão epidérmico de antepaís - 3143
# Bacia de Irecê - 3147
# cinturão - 3150
# depósitos carbonáticos - 3196
# Grupo Una - 3202
# sucessões siliciclásticas - 3206
# sucessões evaporíticas - 3242
# cinturões de antepaís - 3294
# Bacia de Irecê - 3401
# Bacia de Irecê - 3434
# Bacia de Irecê - 3466
# cinturão de antepaís - 3489
# Cráton do São Francisco - 3522
# Pré-Cambriano - 3526
# Ediacarano - 3531
# Supergrupo Espinhaço - 3604
# neoproterozoicas - 3608
# Grupo Una - 3611
# Bacia de Irecê - 3625
# neoproterozoicas - 3652
# Cráton do São Francisco - 3660
# cinturão epidérmico de antepaís - 3728
# Bacia de Irecê - 3732
# Cráton do São Francisco - 3762
# cinturão - 3816
# Bacia de Irecê - 3840
# cinturão - 3843
# cinturão epidérmico de antepaís - 3891
# Bacia de Irecê - 3895
# unidades carbonáticas - 3948
# Grupo Una - 3951
# substrato siliciclástico - 3955
# rochas siliciclásticas - 3960
# Supergrupo Espinhaço - 3963
# Bacia de Irecê - 4000
# cinturão - 4038
# Cráton do São Francisco - 4073
# cinturão epidérmico de antepaís - 4081
# Bacia de Irecê - 4085
# cinturão - 4113
# 560 - 580 Ma - 4119
# Cráton do São Francisco - 4158
# 668 e 540 Ma - 4163
# cinturão epidérmico de antepaís - 4177
# Bacia de Irecê - 4181
# 580 e 540 Ma - 4186
# cráton - 4215
# Bacia de Irecê - 13
# neoproterozoicas - 21
# Cráton do São Francisco - 29
# Bacia de Irecê - 113
# sinclinal - 124
# Cráton do São Francisco - 143
# tectônico N-S - 153
# dobras - 159
# falhas E-W - 162
# Sistema de Dobras - 207
# Empurrões - 209
# Bacia de Irecê - 233
# sinclinal - 248
# Grupo Una - 281
# Supergrupo Espinhaço - 288
# Bacia de Irecê - 294
# Bacia de Irecê - 324
# Cráton do São Francisco - 351
# estruturação E-W - 394
# Grupo Una - 399
# sinclinal - 423
# Pré-cambriano - 506
# neoproterozoicas - 519
# Ciclo Brasiliano - 544
# neoproterozoicos - 642
# Bacia de Irecê - 646
# neoproterozoico - 692
# Cráton do São Francisco - 702
# Bacia de Irecê - 712
# Cráton do São Francisco - 721
# Aulacógeno Paramirim - 727
# Bacia de Irecê - 780
# siliciclástica - 788
# rift-sag - 824
# Grupo Una - 828
# neoproterozoica - 832
# Supergrupo Espinhaço - 841
# discordância erosiva - 847
# Bacia de Irecê - 859
# Bebedouro - 865
# Salitre - 867
# Formação Bebedouro - 871
# diamictitos - 876
# pelitos - 878
# arenitos - 880
# influência glacial - 884
# Formação Bebedouro - 918
# Formação Salitre - 922
# Bacia de Irecê - 931
# carbonática - 937
# regressivo-transgressivos - 960
# Pré-Cambrianas - 977
# Fanerozoica - 982
# Aulacógeno Paramirim - 1022
# pré-cambrianas - 1033
# Aulacógeno Paramirim - 1039
# Sistema de Dobramentos - 1056
# Empurrões - 1058
# Supergrupo Espinhaço - 1069
# Grupo Una - 1075
# dobramentos regionais - 1089
# direção NNW-SSE - 1097
# zonas de cisalhamento - 1116
# falhas de empurrão - 1145
# Aulacógeno Paramirim - 1184
# falhas normais - 1196
# paleo / mesoproterozoicas - 1199
# Bacia de Irecê - 1229
# carbonáticas - 1237
# Grupo Una - 1241
# Bacia de Irecê - 1251
# Ciclo Brasiliano - 1261
# Dobramentos - 1271
# Empurrões - 1273
# neoproterozoicas - 1283
# Grupo Una - 1286
# leque imbricado - 1293
# Aulacógeno do Paramirim - 1309
# calha sinclinal - 1319
# Bacia de Irecê - 1327
# Cráton do São Francisco - 1341
# carbonatos - 1344
# Formação Salitre - 1347
# falhas - 1354
# dobras - 1356
# carbonática - 1386
# Bacia de Irecê - 1416
# chevron - 1434
# charneiras E-W - 1437
# falhas de orientação - 1457
# dobra - 1473
# Sinclinal - 1501
# cisalhamento - 1525
# Grupo Una - 1540
# Supergrupo Espinhaço - 1546
# carbonáticas - 1554
# Bacia de Irecê - 1571
# Bacia de Irecê - 1579
# Bacia de Irecê - 1622
# tension gashes - 1652
# Bacia de Irecê - 1740
# carbonáticas - 1983
# Grupo Una - 1986
# eixo do sinclinal - 2101
# estrutura sinclinal - 2176
# Sinclinal - 2180
# Dobramentos - 2255
# Empurrões - 2257
# falhas - 2271
# dobras - 2273
# estrutura sinclinal - 2280
# falhas direcionais - 2333
# empurrão - 2350
# sinclinal - 2391
# falhas de empurrão - 2404
# falhas direcionais - 2416
# falhas de borda - 2449
# falhas de empurrão - 2460
# falhas de empurrão - 2523
# falha antitética - 2551
# folhelhos - 2612
# argilitos - 2614
# margas - 2616
# falha de empurrão - 2623
# sinistral - 2646
# Bacia de Irecê - 2662
# sinclinal - 2807
# dobras - 2814
# falhas - 2816
# falhas de empurrão - 2834
# Bacia de Irecê - 3147
# sinclinal - 3165
# Grupo Una - 3202
# siliciclásticas - 3206
# evaporíticas - 3242
# tipo pop-up - 3283
# sinclinal - 3319
# Sinclinal - 3331
# falhas de empurrão - 3352
# Bacia de Irecê - 3401
# Bacia de Irecê - 3434
# sinclinal - 3453
# Bacia de Irecê - 3466
# Dobras - 3475
# Empurrões - 3477
# Aulacógeno do Paramirim - 3506
# Cráton do São Francisco - 3522
# Pré-Cambriano - 3526
# Ediacarano - 3531
# Orógeno Araçuaí - 3537
# Dobramentos - 3545
# Empurrões - 3547
# Aulacógeno do Paramirim - 3570
# dobras regionais - 3589
# Supergrupo Espinhaço - 3604
# neoproterozoicas - 3608
# Grupo Una - 3611
# Bacia de Irecê - 3625
# sinclinal - 3639
# Cráton do São Francisco - 3660
# sin-colisional - 3699
# Orógeno Araçuaí - 3702
# granitogênese - 3715
# Bacia de Irecê - 3732
# sinclinal - 3743
# Cráton do São Francisco - 3762
# Bacia de Irecê - 3840
# Dobras - 3867
# Empurrões - 3869
# Bacia de Irecê - 3895
# carbonáticas - 3948
# Grupo Una - 3951
# siliciclástico - 3955
# siliciclásticas - 3960
# Supergrupo Espinhaço - 3963
# Bacia de Irecê - 4000
# sinclinal - 4043
# Cráton do São Francisco - 4073
# Bacia de Irecê - 4085
# Sinclinal - 4101
# Cráton do São Francisco - 4158
# Bacia de Irecê - 4181
# Dobras - 4199
# Empurrões - 4201
# Bacia de Irecê - 13
# neoproterozoicas - 21
# tectônica - 55
# cinturão epidérmico - 58
# cinturão epidérmico - 107
# Bacia de Irecê - 113
# sinclinal - 124
# tectônico - 152
# dobras - 159
# falhas - 161
# deformação - 170
# falhas direcionais - 176
# cinturão - 189
# Sistema de Dobras e Empurrões - 209
# Cinturão - 227
# Bacia de Irecê - 233
# sinclinal - 248
# substrato - 254
# carbonáticas - 278
# Grupo Una - 281
# substrato - 284
# Supergrupo Espinhaço - 288
# Bacia de Irecê - 294
# Cinturão epidérmico - 297
# Bacia de Irecê - 324
# neoproterozoicas - 342
# tectônico - 381
# estratigráfico - 383
# tectônicos - 388
# sedimentos - 396
# Grupo Una - 399
# cinturão epidérmico - 406
# cinturão - 416
# sinclinal - 423
# tectônicos - 440
# cinturão epidérmico - 471
# tectônicos - 493
# Pré-cambriano - 506
# neoproterozoicas - 519
# fases deformacionais - 525
# deformação - 560
# cinturão epidérmico - 566
# tectonismo - 585
# cinturão - 627
# cinturão epidérmico - 635
# neoproterozoicos - 642
# Bacia de Irecê - 646
# cinturão - 691
# neoproterozoico - 692
# geotectônica - 697
# faixas dobradas - 706
# Bacia de Irecê - 712
# sedimentos - 733
# pré-cambrianos - 734
# Supergrupo Espinhaço - 737
# Grupo Una - 741
# embasamento - 746
# arqueano - 747
# paleoproterozoico - 749
# Supergrupo Espinhaço - 766
# paleo - mesoproterozoico - 770
# substrato - 775
# Bacia de Irecê - 780
# siliciclástica - 788
# sequências deposicionais - 816
# sedimentadas - 818
# rift-sag - 824
# Grupo Una - 828
# neoproterozoica - 832
#  - 838
# Supergrupo Espinhaço - 841
# discordância erosiva - 847
# Bacia de Irecê - 859
# formações Bebedouro e Salitre - 867
# Formação Bebedouroencerra - 872
# diamictitos - 876
# pelitos - 878
# arenitos - 880
# glacial - 884
# sedimentos glaciogênicos - 915
# Formação Bebedouro - 918
# Formação Salitre - 922
# Bacia de Irecê - 931
# carbonática - 937
# dolomitizada - 941
# ciclos regressivo-transgressivos - 960
# Embasamento - 972
# Fanerozoica - 982
# pré-cambrianas - 1033
# sistemas deformacionais - 1045
# Sistema de Dobramentos e Empurrões - 1058
# Supergrupo Espinhaço - 1069
# Grupo Una - 1075
# cinturão deformacional - 1081
# dobramentos - 1088
# dobramentos - 1105
# mesoestruturas - 1109
# zonas de cisalhamento - 1116
# deformação - 1124
# falhas de empurrão - 1145
# embasamento - 1163
# foliação tectônica - 1173
# falhas normais - 1196
# paleo / mesoproterozoicas - 1199
# sistema deformacional - 1204
# cinturão epidérmico - 1210
# cinturão - 1220
# Bacia de Irecê - 1229
# carbonáticas - 1237
# neoproterozoicas - 1238
# Grupo Una - 1241
# cinturão epidérmico - 1245
# Bacia de Irecê - 1251
# tectônico tardio - 1257
# Sistema de Dobramentos e Empurrões - 1273
# neoproterozoicas - 1283
# Grupo Una - 1286
# leque imbricado - 1293
# calha sinclinal - 1319
# Bacia de Irecê - 1327
# carbonatos - 1344
# Formação Salitre - 1347
# falhas e dobras - 1356
# carbonática - 1386
# zona axial - 1412
# Bacia de Irecê - 1416
# cinturão - 1429
# dobras em chevron - 1434
# charneiras - 1436
# falhas - 1455
# dobra - 1473
# Sinclinal - 1501
# zonas de cisalhamento - 1525
# Grupo Una - 1540
# Supergrupo Espinhaço - 1546
# carbonáticas - 1554
# cinturão epidérmico - 1563
# Bacia de Irecê - 1571
# Bacia de Irecê - 1579
# cinturão epidérmico - 1583
# Arcabouço estrutural - 1615
# Bacia de Irecê - 1622
# fraturas - 1644
# dobras - 1686
# cinturão epidérmico - 1736
# Bacia de Irecê - 1740
# tectônico - 1744
# falhas - 1763
# cinturões compressivos - 1787
# friccional - 1793
# descolamento basal - 1797
# dobras - 1815
# cinturão - 1822
# quartzo - 1903
# granulometria - 1913
# camada - 1934
# comportamento newtoniano e viscosidade - 1956
# camada - 1970
# areia - 1972
# carbonáticas - 1983
# Grupo Una - 1986
# sinclinal - 2101
# tectônico - 2108
# zona axial - 2113
# deformação - 2116
# deformação - 2146
# camada - 2157
# areia - 2159
# sinclinal - 2176
# Sistema de Dobramentos e Empurrões - 2257
# cinturão - 2269
# falhas - 2271
# dobras - 2273
# sinclinal - 2280
# pacote sedimentar - 2290
# camada - 2295
# falhas direcionais - 2333
# falhas de empurrão - 2350
# deformação - 2377
# sinclinal - 2391
# falhas de empurrão - 2404
# falhas direcionais - 2416
# falhas - 2447
# sinclinal - 2454
# falhas de empurrão - 2460
# falhas - 2476
# falhas de empurrão - 2523
# depressões - 2529
# zona axial - 2543
# sinclinal - 2545
# falha - 2550
# retroempurrão - 2558
# empurrão - 2565
# folhelhos - 2612
# argilitos - 2614
# margas - 2616
# falha de empurrão - 2623
# direcional destral - 2627
# sinistral - 2646
# Bacia de Irecê - 2662
# fraturas axiais - 2674
# camadas - 2680
# cinturão - 2732
# sinclinal - 2745
# cinturão - 2778
# calha sinclinal - 2807
# dobras - 2814
# falhas - 2816
# falhas de empurrão - 2834
# cinturões epidérmicos - 2843
# pacote sedimentar - 2872
# substrato - 2877
# cinturões epidérmicos - 2905
# falhas - 2913
# substrato - 2936
# cinturões - 2946
# falhas - 2951
# dobradas - 2965
# cinturões - 2977
# substrato - 2989
# pacote estratigráfico - 2996
# cinturões epidérmicos - 3027
# substratos - 3030
# cinturão - 3067
# cinturão - 3103
# cinturão epidérmico - 3141
# Bacia de Irecê - 3147
# cinturão - 3150
# sinclinal - 3165
# Grupo Una - 3202
# siliciclásticas - 3206
# Deformação - 3217
# sinclinal - 3319
# Sinclinal - 3331
# ­falhas - 3340
# falhas de empurrão - 3352
# falhas - 3358
# depressões antiformais - 3387
# Bacia de Irecê - 3401
# deformação - 3415
# tectônica - 3427
# Bacia de Irecê - 3434
# afloramento - 3450
# sinclinal - 3453
# Bacia de Irecê - 3466
# Sistema de Dobras e Empurrões - 3477
# cinturão - 3487
# sistemas deformacionais - 3498
# intracratônica - 3510
# Pré-Cambriano - 3526
# Ediacarano - 3531
# Sistema de Dobramentos e Empurrões - 3547
# cinturão - 3553
# tectônica - 3581
# dobras - 3588
# depósitos - 3601
# Supergrupo Espinhaço - 3604
# neoproterozoicas - 3608
# Grupo Una - 3611
# Bacia de Irecê - 3625
# calha sinclinal - 3639
# neoproterozoicas - 3652
# tectônica - 3684
# 560 - 580 Ma - 3692
# sin-colisional - 3699
# deformação - 3708
# cinturão epidérmico - 3726
# Bacia de Irecê - 3732
# sinclinal - 3743
# tectônico - 3771
# dobras - 3786
# falhas - 3788
# fraturas - 3794
# cinturão - 3816
# falhas direcionais - 3824
# Bacia de Irecê - 3840
# cinturão - 3843
# Sistema de Dobras e Empurrões - 3869
# cinturão epidérmico - 3889
# Bacia de Irecê - 3895
# sinclinal - 3919
# substrato - 3925
# carbonáticas - 3948
# Grupo Una - 3951
# substrato - 3954
# siliciclástico - 3955
# siliciclásticas - 3960
# Supergrupo Espinhaço - 3963
# depressões antiformais - 3970
# deformação - 3983
# Bacia de Irecê - 4000
# cinturão - 4038
# sinclinal - 4043
# cinturão epidérmico - 4079
# Bacia de Irecê - 4085
# Sinclinal - 4101
# 560 - 580 Ma - 4119
# deformação - 4150
# 668 e 540 Ma - 4163
# cinturão epidérmico - 4175
# Bacia de Irecê - 4181
# 580 e 540 Ma - 4186
# Sistema de Dobras e Empurrões - 4201
# deformação - 4208
# faixas marginais - 4211
# sistema de nappes - 4221
# 416
